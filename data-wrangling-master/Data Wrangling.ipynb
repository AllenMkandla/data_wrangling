# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Examine the data frame for duplicates (based on ID), and drop any duplicates that exist. Use an assert statement to check that the new data frame is the length of the unique entries of the original data frame.

# %%
p_df = pd.read_csv('data/personality_scores.csv', sep=';')
d_df = pd.read_csv('data/departments.csv', sep=';')
p_df.head()
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
p_df.isnull().sum()
# Out:
# ID                                                           0
# Section 5 of 6 [I am always prepared.]                       0
# Section 5 of 6 [I am easily disturbed.]                      0
# Section 5 of 6 [I am exacting (demanding) in my work.]       0
# Section 5 of 6 [I am full of ideas.]                         0
#                                                           ...
# Unnamed: 65                                               1555
# Unnamed: 66                                               1555
# Unnamed: 67                                               1555
# Unnamed: 68                                               1555
# IPIP_HIGH_RISK                                            1555
# Length: 70, dtype: int64

# %% [markdown]
# Checking for duplicates

# %%
p_df['ID'].is_unique
# Out:
# True

# %% [markdown]
# There are no duplicates, if we had found any we could use the function `duplicate_removal` below to remove them.

# %%
def duplicate_removal():
    first = len(p_df.ID)
    duplicates = len(p_df.drop_duplicates(subset='ID', keep='first'))
    return first - duplicates
duplicate_removal()
# Out:
# 0

# %% [markdown]
# Since there are no duplicates the original data has not been changed. We could check this with;
# ```
# original_df = pd.read_csv('data/personality_scores.csv', sep=';')
# clean_df = original_df.drop_duplicates(subset='ID')
# assert len(original_df) == len(clean_df)
# ```

# %%
p_df = p_df.set_index('ID')

p_df.head()
# p_df.shape
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# ...

# %%
p_df = p_df.dropna(axis = 1)
p_df.head()
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# ...

# %% [markdown]
# 2. Create new columns containing the total score of each of the personality test subscales.

# %%
def total_score(score, subscale):
    x = sum([eval(score[i])[1] for i in range(50) if eval(score[i])[0] == subscale])
    return(x)
# total_score()

# %%
[eval(score[i])[1] for i in range(50) if eval(score[i])[0] == subscale]
[output condition]

# %% [markdown]
# List comprehenssion - `[]`
# eval()

# %% [markdown]
# Map scores to traits
#
# To do:
# * Look up `map()` to see if the code below can't be improved

# %%
p_df['Extraversion'] = p_df.apply(lambda row: total_score(row, 1), axis=1)
p_df['Agreeableness'] = p_df.apply(lambda row: total_score(row, 2), axis=1)
p_df['Conscientiousness'] = p_df.apply(lambda row: total_score(row, 3), axis=1)
p_df['Neuroticism'] = p_df.apply(lambda row: total_score(row, 4), axis=1)
p_df['Intellect'] = p_df.apply(lambda row: total_score(row, 5), axis=1)

# %%
p_df.head()
# Out:
#    Section 5 of 6 [I am always prepared.]  \
# ID
# 0                                  (3, 5)
# 1                                  (3, 5)
# 2                                  (3, 5)
# 3                                  (3, 5)
# 4                                  (3, 3)
#
#    Section 5 of 6 [I am easily disturbed.]  \
# ID
# 0                                   (4, 5)
# 1                                   (4, 5)
# 2                                   (4, 3)
# 3                                   (4, 5)
# 4                                   (4, 5)
#
#    Section 5 of 6 [I am exacting (demanding) in my work.]  \
# ID
# 0                                              (3, 5)
# 1                                              (3, 5)
# 2                                              (3, 3)
# 3                                              (3, 3)
# 4                                              (3, 3)
#
#    Section 5 of 6 [I am full of ideas.]  \
# ID
# 0                                (5, 5)
# ...

# %%
p_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555 entries, 0 to 1554
# Data columns (total 55 columns):
# Section 5 of 6 [I am always prepared.]                                      1555 non-null object
# Section 5 of 6 [I am easily disturbed.]                                     1555 non-null object
# Section 5 of 6 [I am exacting (demanding) in my work.]                      1555 non-null object
# Section 5 of 6 [I am full of ideas.]                                        1555 non-null object
# Section 5 of 6 [I am interested in people.]                                 1555 non-null object
# Section 5 of 6 [I am not interested in abstract ideas.]                     1555 non-null object
# Section 5 of 6 [I am not interested in other people's problems.]            1555 non-null object
# Section 5 of 6 [I am not really interested in others.]                      1555 non-null object
# ...
